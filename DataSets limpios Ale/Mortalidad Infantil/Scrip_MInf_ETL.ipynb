# %% [markdown]
# LLAMAMOS LA API del BANCO MUNDIAL QUE DE MODO PREVIO INSTALE POR CONSOLA

# %%
import wbgapi as wb
import pandas as pd
import numpy  as np

# %% [markdown]
# CONSULTA DE INFO OBTENIBLE DE LA API

# %% [markdown]
# DATOS DE MORTALIDAD EN BEBES RECIEN NACIDO CADA 1000 PARA EL PAIS DE ARGENTINA, UTILIZAMOS EL CODIGO
# QUE PROVEE EL BANCO MUNDIAL PARA LA TEMATICA A TRATAR: (SP.DYN.IMRT.IN)

# %%
wb.data.DataFrame(['SP.DYN.IMRT.IN'], 'ARG', mrv=50)
# Out:
#          YR1971  YR1972  YR1973  YR1974  YR1975  YR1976  YR1977  YR1978  \
# economy
# ARG        58.3    57.5    56.4    54.8    52.8    50.1    47.0    43.6
#
#          YR1979  YR1980  ...  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy                  ...
# ARG        40.1    36.9  ...    12.4    11.9    11.3    10.8    10.2     9.7
#
#          YR2017  YR2018  YR2019  YR2020
# economy
# ARG         9.2     8.6     8.1     7.6
#
# [1 rows x 50 columns]

# %% [markdown]
# PARA REALIZAR OTRA PRUEBA TOMO LOS DATOS PAR EL PAIS BRASIL

# %%
wb.data.DataFrame(['SP.DYN.IMRT.IN'], 'BRA', mrv=50)
# Out:
#          YR1971  YR1972  YR1973  YR1974  YR1975  YR1976  YR1977  YR1978  \
# economy
# BRA        99.9    97.5    95.1    92.8    90.4    87.9    85.3    82.6
#
#          YR1979  YR1980  ...  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy                  ...
# BRA        79.7    76.6  ...    16.0    15.4    14.9    14.6    14.2    15.0
#
#          YR2017  YR2018  YR2019  YR2020
# economy
# BRA        13.8    13.6    13.3    13.1
#
# [1 rows x 50 columns]

# %% [markdown]
# Datos de MORTALIDAD INFANTIL SOBRE LA CIFRA DE 1000 NACIMIENTOS de PAISES SELECCIONADOS

# %%
wb.data.DataFrame(['SP.DYN.IMRT.IN'], ['ARG','BRA','COL','CAN','CHL','MEX','ECU','USA','URY', 'PAN','VEN''EGY','CMR','NGA','ZAF','ETH','DEU','BEL','ESP','FRA','NDL','GBR','ITA','CHE','UKR', 'RUS','EGY','CMR','NGA','ZAF','ETH','CHN','JPN','KOR','MYS','IND','AFG'], mrv=50)
# Out:
#          YR1971  YR1972  YR1973  YR1974  YR1975  YR1976  YR1977  YR1978  \
# economy
# AFG       198.4   194.5   190.7   186.7   182.7   178.8   174.9   170.8
# ARG        58.3    57.5    56.4    54.8    52.8    50.1    47.0    43.6
# BEL        19.7    18.7    17.7    16.7    15.7    14.9    14.1    13.5
# BRA        99.9    97.5    95.1    92.8    90.4    87.9    85.3    82.6
# CAN        17.6    16.7    15.9    15.0    14.1    13.3    12.5    11.7
# CHE        14.3    13.6    12.8    12.0    11.2    10.5     9.8     9.2
# CHL        66.1    65.2    63.4    59.7    54.1    47.5    41.0    35.3
# CHN        76.0    72.5    68.9    65.3    61.6    58.1    54.8    51.7
# CMR       121.6   118.5   116.3   114.9   114.2   113.6   112.9   111.8
# COL        68.1    65.7    63.2    60.7    58.1    55.5    52.8    50.2
# DEU        21.3    20.6    19.7    18.8    17.7    16.6    15.5    14.4
# ECU        93.4    90.9    88.1    84.9    81.5    78.2    75.1    72.2
# ...

# %%
Df_mort_infantil = wb.data.DataFrame(['SP.DYN.IMRT.IN'], ['ARG','BRA','COL','CAN','CHL','MEX','ECU','USA','URY', 'PAN','VEN''EGY','CMR','NGA','ZAF','ETH','DEU','BEL','ESP','FRA','NDL','GBR','ITA','CHE','UKR', 'RUS','EGY','CMR','NGA','ZAF','ETH','CHN','JPN','KOR','MYS','IND','AFG'], mrv=50)

# %%
Df_mort_infantil.info
# Out:
# <bound method DataFrame.info of          YR1971  YR1972  YR1973  YR1974  YR1975  YR1976  YR1977  YR1978  \
# economy
# AFG       198.4   194.5   190.7   186.7   182.7   178.8   174.9   170.8
# ARG        58.3    57.5    56.4    54.8    52.8    50.1    47.0    43.6
# BEL        19.7    18.7    17.7    16.7    15.7    14.9    14.1    13.5
# BRA        99.9    97.5    95.1    92.8    90.4    87.9    85.3    82.6
# CAN        17.6    16.7    15.9    15.0    14.1    13.3    12.5    11.7
# CHE        14.3    13.6    12.8    12.0    11.2    10.5     9.8     9.2
# CHL        66.1    65.2    63.4    59.7    54.1    47.5    41.0    35.3
# CHN        76.0    72.5    68.9    65.3    61.6    58.1    54.8    51.7
# CMR       121.6   118.5   116.3   114.9   114.2   113.6   112.9   111.8
# COL        68.1    65.7    63.2    60.7    58.1    55.5    52.8    50.2
# DEU        21.3    20.6    19.7    18.8    17.7    16.6    15.5    14.4
# ...

# %% [markdown]
# VAMOS A VOLCAR LOS DATOS OBTENIDOS EN UN CSV PARA QUEDARNOSLO DE MODO LOCAL PARA ANALISIS O FUTUROS ESTUDIOS, O SOLO MANEJO LOCAL

# %%
Df_mort_infantil.to_csv('mortalidad_infantil.csv')
